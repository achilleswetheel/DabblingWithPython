# %% [markdown]
# Write a for loop the prints out all the element between -5 and 5 using the range function.

# %%
for i in range(-5,5):
        print(i)
# Out:
# -5
# -4
# -3
# -2
# -1
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Print the elements of the following list:
# <code>Genres=[ 'rock', 'R&B', 'Soundtrack', 'R&B', 'soul', 'pop']</code>
# Make sure you follow Python conventions.

# %%
Genres=[ 'rock', 'R&B', 'Soundtrack', 'R&B', 'soul', 'pop']

# %%
for g in Genres:
    print(g)
# Out:
# rock
# R&B
# Soundtrack
# R&B
# soul
# pop

# %% [markdown]
# Write a for loop that prints out the following list: <code>squares=['red', 'yellow', 'green', 'purple', 'blue']</code>

# %%
for i in ['red', 'yellow', 'green', 'purple', 'blue']:
    print(i)
# Out:
# red
# yellow
# green
# purple
# blue

# %% [markdown]
# Write a while loop to display the values of the Rating of an album playlist stored in the list PlayListRatings. If the score is less than 6, exit the loop. The list PlayListRatings is given by: PlayListRatings = [10, 9.5, 10, 8, 7.5, 5, 10, 10]

# %%
PlayListRatings = [10, 9.5, 10, 8, 7.5, 5, 10, 10]
fir = PlayListRatings[0]
i = 1
while(fir>6):
    print(fir)
    fir = PlayListRatings[i]
    i = i+1
# Out:
# 10
# 9.5
# 10
# 8
# 7.5

# %%
PlayListRatings = [10, 9.5, 10, 8, 7.5, 5, 10, 10]
i = 1
Rating = PlayListRatings[0]
while(Rating >= 6):
    print(Rating)
    Rating = PlayListRatings[i]
    i = i + 1
# Out:
# 10
# 9.5
# 10
# 8
# 7.5

# %% [markdown]
# Write a while loop to copy the strings <code>'orange'</code> of the list <code>squares</code> to the list <code>new_squares</code>. Stop and exit the loop if the value on the list is not <code>'orange'</code>:

# %%
squares = ['orange', 'orange', 'purple', 'blue ', 'orange']
new_squares = []
i = 0
j = 0
while (i<len(squares)):
    if (squares[i] == 'orange'):        
        new_squares[j] = 'orange'
    i = i+1
    j = j+1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-9f4c3e16896a> in <module>
#       5 while (i<len(squares)-1):
#       6     if (squares[i] == 'orange'):
# ----> 7         new_squares[j] = 'orange'
#       8     i = i+1
#       9     j = j+1
#
# IndexError: list assignment index out of range

# %%
squares = ['orange', 'orange', 'purple', 'blue ', 'orange']
print(len(squares))
# Out:
# 5
